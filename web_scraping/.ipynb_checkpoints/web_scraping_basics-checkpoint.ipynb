# %%
import requests

# %%
result = requests.get('https://en.wikipedia.org/wiki/Yuval_Noah_Harari')

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Yuval Noah Harari - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"452cff90-f38f-4069-bac2-79b32d0bfd4c","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Yuval_Noah_Harari","wgTitle":"Yuval Noah Harari","wgCurRevisionId":1129452856,"wgRevisionId":1129452856,"wgArticleId":36254359,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: uses authors parameter","CS1 German-language sources (de)","Articles with short description","Short description is differ
# ...

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(result.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Yuval Noah Harari - Wikipedia</title>
# ...

# %%
soup.select('title')[0].getText()
# Out:
# 'Yuval Noah Harari - Wikipedia'

# %%
site_paragraphs = soup.select('p')

# %%
type(site_paragraphs[0])
# Out:
# bs4.element.Tag

# %%
soup.select('.toctext')[0].getText()
# Out:
# 'Early life'

# %%
for i in soup.select('.toctext'):
    print(i.text)
# Out:
# Early life
# Academic career
# Literary career
# Personal life
# Awards and recognition
# Controversy
# Critical reception
# Published works
# Books
# Articles
# References
# External links

# %%
portrait = soup.select('.image')[0]

# %%
portrait
# Out:
# <a class="image" href="/wiki/File:Yuval_Noah_Harari_cropped.jpg"><img alt="Yuval Noah Harari cropped.jpg" data-file-height="408" data-file-width="346" decoding="async" height="259" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Yuval_Noah_Harari_cropped.jpg/220px-Yuval_Noah_Harari_cropped.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Yuval_Noah_Harari_cropped.jpg/330px-Yuval_Noah_Harari_cropped.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/f/f9/Yuval_Noah_Harari_cropped.jpg 2x" width="220"/></a>

# %%
portrait_link = requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Yuval_Noah_Harari_cropped.jpg/220px-Yuval_Noah_Harari_cropped.jpg')

# %%
f = open('harari_image.jpg','wb')

# %%
f.write(portrait_link.content)
# Out:
# 13059

# %%
f.close
# Out:
# <function BufferedWriter.close>
